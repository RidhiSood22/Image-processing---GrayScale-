# %% [markdown]
# <a href="https://colab.research.google.com/github/RidhiSood22/Image-processing---GrayScale-/blob/main/Image_Proprocessing_GrayScale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Necessaary Libraries
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img_path = "/content/download.jpeg"
img = cv2.imread(img_path)
print(img.shape)
# Out:
# (148, 215, 3)

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image, cmap='gray')
plt.show()
print(gray_image.shape)
# Out:
# (148, 215)
